# %% [markdown]
# # Generate feature: count of previous years' HPVs

# %%
import csv
import pandas as pd
import numpy as np
import processing 
from datetime import datetime as dt
import pylab as pl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def convert_to_datetime(series_row, date_format):
    if str(series_row) == 'nan':
        return float('nan')
    return dt.strptime(series_row, date_format)
    

def convert_to_month(series_row):
    if str(series_row) == 'NaT' or str(series_row)== 'nan':
        return float('nan')
    else:
        return str(series_row.month)

def convert_to_year(series_row):
    if str(series_row) == 'NaT' or str(series_row)== 'nan':
        return float('nan')
    else:
        return str(series_row.year)

def get_month_year_col(df, date_column, date_format):
    df[date_column+'_datetime'] = df[date_column].apply(convert_to_datetime, date_format=date_format)
    df[date_column+'_month'] = df[date_column+'_datetime'].apply(convert_to_month)
    df[date_column+'_year'] = df[date_column+'_datetime'].apply(convert_to_year)
    return df

# %%
# Read files
violhist = pd.read_csv('ICIS-AIR_VIOLATION_HISTORY.csv')
fce = pd.read_csv('ICIS-AIR_FCES_PCES.csv')

# %%
violhist.columns
# Out:
# Index(['PGM_SYS_ID', 'ACTIVITY_ID', 'AGENCY_TYPE_DESC', 'STATE_CODE',
#        'AIR_LCON_CODE', 'COMP_DETERMINATION_UID', 'ENF_RESPONSE_POLICY_CODE',
#        'PROGRAM_CODES', 'PROGRAM_DESCS', 'POLLUTANT_CODES', 'POLLUTANT_DESCS',
#        'EARLIEST_FRV_DETERM_DATE', 'HPV_DAYZERO_DATE', 'HPV_RESOLVED_DATE'],
#       dtype='object')

# %%
fce.columns
# Out:
# Index(['PGM_SYS_ID', 'ACTIVITY_ID', 'STATE_EPA_FLAG', 'ACTIVITY_TYPE_CODE',
#        'ACTIVITY_TYPE_DESC', 'COMP_MONITOR_TYPE_CODE',
#        'COMP_MONITOR_TYPE_DESC', 'ACTUAL_END_DATE', 'PROGRAM_CODES'],
#       dtype='object')

# %%
#Change date columns
violhist = get_month_year_col(violhist, 'EARLIEST_FRV_DETERM_DATE', '%m-%d-%Y')
violhist = get_month_year_col(violhist, 'HPV_DAYZERO_DATE', '%m-%d-%Y')
violhist = get_month_year_col(violhist, 'HPV_RESOLVED_DATE', '%m-%d-%Y')

# %%
#removing FRVs
violhist = violhist[violhist.ENF_RESPONSE_POLICY_CODE != 'FRV']

# %%
#Steps before merge
violhist['year'] = violhist['HPV_DAYZERO_DATE_year']
fce = get_month_year_col(fce, 'ACTUAL_END_DATE', '%m-%d-%Y')

# %%
#Left merge into violation history file
merged_hpv_fce = pd.merge(violhist, fce, how='left', left_on=['PGM_SYS_ID', 'HPV_DAYZERO_DATE'], right_on=['PGM_SYS_ID','ACTUAL_END_DATE'])

# %%
merged_hpv_fce.head(3)
# Out:
#            PGM_SYS_ID  ACTIVITY_ID_x AGENCY_TYPE_DESC STATE_CODE  \
# 0  CT0000000900700108     3400302038            State         CT
# 1  CT0000000900900110     3400302044            State         CT
# 2  CT0000000900900110     3400302045            State         CT
#
#   AIR_LCON_CODE     COMP_DETERMINATION_UID ENF_RESPONSE_POLICY_CODE  \
# 0           NaN  CT000A0000090070010800028                      HPV
# 1           NaN  CT000A0000090090011000026                      HPV
# 2           NaN  CT000A0000090090011000037                      HPV
#
#   PROGRAM_CODES_x                                      PROGRAM_DESCS  \
# 0          CAASIP  State Implementation Plan for National Primary...
# 1          CAASIP  State Implementation Plan for National Primary...
# 2          CAASIP  State Implementation Plan for National Primary...
#
#        POLLUTANT_CODES         ...          STATE_EPA_FLAG ACTIVITY_TYPE_CODE  \
# 0  300000005 300000323         ...                     NaN                NaN
# 1  300000005 300000323         ...                     NaN                NaN
# 2      10461 300000005         ...                     NaN                NaN
#
#   ACTIVITY_TYPE_DESC COMP_MONITOR_TYPE_CODE COMP_MONITOR_TYPE_DESC  \
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN                    NaN
#
#   ACTUAL_END_DATE PROGRAM_CODES_y ACTUAL_END_DATE_datetime  \
# 0             NaN             NaN                      NaN
# 1             NaN             NaN                      NaN
# 2             NaN             NaN                      NaN
#
#   ACTUAL_END_DATE_month ACTUAL_END_DATE_year
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
#
# [3 rows x 35 columns]

# %%
# Find violations that resulted from something other than an inspection 
viol_by_other = merged_hpv_fce
viol_by_other.COMP_MONITOR_TYPE_CODE.fillna(0, inplace=True)   #this will be NaN because it was not inspected
viol_by_other = viol_by_other[viol_by_other['COMP_MONITOR_TYPE_CODE'] == 0]  #violations not resulting from inspections

# %%
# Get the columns needed
viol_by_other = viol_by_other[['PGM_SYS_ID','year']]
viol_other_year = viol_by_other.groupby(['PGM_SYS_ID','year']).size().reset_index() # to get count of HPV by year
violhist2 = violhist[['PGM_SYS_ID','year']]

# %%
# Outer merge
merged_viols = pd.merge(violhist2,viol_other_year, how = 'outer', on = ['PGM_SYS_ID','year'])
merged_viols.rename(columns={'year': 'Year', 0:'NonInspection_HPV_Count'}, inplace=True)
merged_viols.NonInspection_HPV_Count.fillna(0, inplace=True)

# %%
print (merged_viols.shape, violhist.shape)
# Out:
# (35489, 3) (35489, 24)

# %%
merged_viols.isnull().sum()  #34 rows are missing years (from original file)
# Out:
# PGM_SYS_ID                  0
# Year                       34
# NonInspection_HPV_Count     0
# dtype: int64

# %%
merged_viols = merged_viols.dropna(axis=0)

# %%
merged_viols.shape
# Out:
# (35455, 3)

# %%
merged_viols  #Final result: Count of non-inspection HPVs by facility by year
# Out:
#                PGM_SYS_ID  Year  NonInspection_HPV_Count
# 0      CT0000000900700108  1996                      1.0
# 1      CT0000000900900110  1996                      1.0
# 2      CT0000000900900110  1998                      2.0
# 3      CT0000000900900110  1998                      2.0
# 4      CT0000000900300125  2005                      0.0
# 5      CT0000000900508907  2010                      0.0
# 6      CT0000000900100078  2007                      1.0
# 7      CT0000000901501125  2013                      1.0
# 8      CT0000000900300171  1998                      2.0
# 9      CT0000000900300171  1998                      2.0
# 10     CT0000000900109058  2008                      1.0
# 11     CT0000000900500464  1994                      1.0
# 12     CT0000000900108858  1998                      1.0
# 13     CT0000000900108858  1997                      1.0
# 14     CT0000000901100054  2008                      1.0
# 15     CT0000000901100407  1998                      1.0
# 16     CT0000000901100038  2006                      1.0
# 17     CT0000000901100038  2009                      0.0
# 18     CT0000000900900001  2006                      0.0
# 19     CT0000000900900016  2010                      0.0
# 20     CT0000000900100013  1998                      2.0
# 21     CT0000000900100013  1998                      2.0
# 22     CT0000000900900004  1996                      1.0
# 23     CT0000000900302470  1993                      1.0
# 24     CT0000000900700003  2002                      1.0
# 25     CT0000000900700003  2004                      1.0
# 26     MA0000002512000866  2010                      1.0
# 27     MA0000002504200461  2000                      1.0
# 28     MA0000002511900487  1993                      1.0
# 29     MA0000002504200307  2006                      1.0
# ...                   ...   ...                      ...
# 35454  CASJV00006029S1738  2012                      0.0
# 35455  CASJV00006047N1252  2014                      1.0
# 35456  TX0000004834100041  2000                      1.0
# 35457  TX0000004835500050  2008                      0.0
# 35458  CASJV00006029S0511  2011                      1.0
# 35460  CASCA0000603700043  2012                      1.0
# 35461  TX0000004848100049  2006                      1.0
# 35463  LA0000002212700024  2014                      1.0
# 35465  TX0000004847300006  2011                      0.0
# 35466  CASJV00006029S1246  2012                      0.0
# 35467  CASJV00006029S1246  2012                      0.0
# 35468  CASJV00006029S1246  2012                      0.0
# 35469  CASJV00006029S1246  2012                      0.0
# 35470  CASJV00006029S1246  2012                      0.0
# 35471  TX0000004843901705  2005                      1.0
# 35472  CASJV00006029S0511  2013                      3.0
# 35473  CASJV00006029S0511  2013                      3.0
# 35474  CASJV00006029S0511  2013                      3.0
# 35475  CASJV00006029S0034  2013                      1.0
# 35476  CASJV00006029S0034  2013                      1.0
# 35477  TX0000004835500018  2005                      1.0
# 35478  TX0000004824500178  2003                      1.0
# 35479  CASJV00006029S0511  2014                      1.0
# 35480  CASJV00006047N1252  2012                      1.0
# 35481  CASJV00006047N1252  2013                      1.0
# 35482  CASJV00006029S1738  2013                      1.0
# 35484  TX0000004848300258  2014                      0.0
# 35485  CASCA0000603700559  2011                      1.0
# 35486  LA0000002210100123  2010                      1.0
# 35488  CASJV00006029S1518  2015                      0.0
#
# [35455 rows x 3 columns]
